# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.model_selection import GridSearchCV
param_grid =  {'criterion':['squared_error','absolute_error','friedman_mse'],
 'max_features': ['sqrt','log2'],
 'splitter':['best','random']}
grid = GridSearchCV(DecisionTreeRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
# fitting the model for grid search
#grid.fit(X_train, y_train)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# GridSearchCV(estimator=DecisionTreeRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': ['sqrt', 'log2'],
#                          'splitter': ['best', 'random']},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'friedman_mse', 'max_features': 'log2', 'splitter': 'best'}: 0.998667156135576

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.016249      0.008882         0.014539        0.008723
# 1        0.021354      0.010384         0.013429        0.004554
# 2        0.029579      0.008184         0.011123        0.007063
# 3        0.023311      0.006986         0.013646        0.004830
# 4        0.058060      0.016431         0.005584        0.004740
# 5        0.037323      0.003827         0.006074        0.004959
# 6        0.044267      0.005861         0.010344        0.000142
# 7        0.034177      0.005651         0.008080        0.004040
# 8        0.014595      0.005232         0.008155        0.004079
# 9        0.012219      0.004163         0.006402        0.008605
# 10       0.012196      0.004091         0.008144        0.004074
# 11       0.014223      0.004978         0.008223        0.004115
#
#    param_criterion param_max_features param_splitter  \
# 0    squared_error               sqrt           best
# 1    squared_error               sqrt         random
# 2    squared_error               log2           best
# 3    squared_error               log2         random
# 4   absolute_error               sqrt           best
# 5   absolute_error               sqrt         random
# 6   absolute_error               log2           best
# 7   absolute_error               log2         random
# 8     friedman_mse               sqrt           best
# 9     friedman_mse               sqrt         random
# 10    friedman_mse               log2           best
# 11    friedman_mse               log2         random
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.688325
# 1   {'criterion': 'squared_error', 'max_features':...           0.684848
# 2   {'criterion': 'squared_error', 'max_features':...           0.740383
# 3   {'criterion': 'squared_error', 'max_features':...           0.639879
# 4   {'criterion': 'absolute_error', 'max_features'...           0.684564
# 5   {'criterion': 'absolute_error', 'max_features'...           0.762607
# 6   {'criterion': 'absolute_error', 'max_features'...           0.731737
# 7   {'criterion': 'absolute_error', 'max_features'...           0.693574
# 8   {'criterion': 'friedman_mse', 'max_features': ...           0.677368
# 9   {'criterion': 'friedman_mse', 'max_features': ...           0.656132
# 10  {'criterion': 'friedman_mse', 'max_features': ...           0.716592
# 11  {'criterion': 'friedman_mse', 'max_features': ...           0.690698
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.557757           0.598076           0.725168
# 1            0.576236           0.689395           0.680323
# 2            0.609780           0.546466           0.746955
# 3            0.558275           0.690096           0.693657
# 4            0.585005           0.679136           0.713013
# 5            0.568740           0.760120           0.675846
# 6            0.589315           0.764788           0.720359
# 7            0.548841           0.673099           0.665035
# 8            0.541307           0.743317           0.675608
# 9            0.620625           0.608246           0.642516
# 10           0.673827           0.697949           0.728699
# 11           0.533924           0.723227           0.685248
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.715068         0.656879        0.066815                9
# 1            0.648541         0.655869        0.042325               10
# 2            0.716099         0.671936        0.079836                5
# 3            0.492289         0.614839        0.078385               12
# 4            0.657137         0.663771        0.043223                6
# 5            0.614920         0.676447        0.077216                3
# 6            0.720488         0.705337        0.060246                2
# 7            0.733705         0.662851        0.061761                7
# 8            0.726355         0.672791        0.070936                4
# 9            0.704826         0.646469        0.033596               11
# 10           0.713828         0.706179        0.018913                1
# 11           0.669413         0.660502        0.065666                8

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 55
# BMI: 35
# Children: 2
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Insurance_charges=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#change the paramter,play with it.
print("Insurance Charges={}".format(Insurance_charges))
# Out:
# Insurance Charges=[12495.29085]
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but DecisionTreeRegressor was fitted with feature names
#   warnings.warn(
