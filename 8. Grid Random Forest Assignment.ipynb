# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
from sklearn.model_selection import GridSearchCV
param_grid = {'criterion':['squared_error','absolute_error','friedman_mse'],
'max_features': [None,'sqrt','log2'],
'n_estimators':[10,100]}
grid = GridSearchCV(RandomForestRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 18 candidates, totalling 90 fits
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# GridSearchCV(estimator=RandomForestRegressor(), n_jobs=-1,
#              param_grid={'criterion': ['squared_error', 'absolute_error',
#                                        'friedman_mse'],
#                          'max_features': [None, 'sqrt', 'log2'],
#                          'n_estimators': [10, 100]},
#              verbose=3)

# %%
# print best parameter after tuning
#print(grid.best_params_)
re=grid.cv_results_
#print(re)
#grid_predictions = grid.predict(X_test)
grid_predictions = grid.predict(independent)
# print classification report
from sklearn.metrics import r2_score
#r_score=r2_score(y_test,grid_predictions)
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'criterion': 'squared_error', 'max_features': 'sqrt', 'n_estimators': 100}: 0.9760668994856521

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.120946      0.004106         0.015207        0.006103
# 1        1.003087      0.036091         0.033390        0.016942
# 2        0.080564      0.004251         0.006911        0.003669
# 3        0.699718      0.031117         0.022043        0.003567
# 4        0.087687      0.005884         0.009411        0.002134
# 5        0.697989      0.005192         0.031417        0.002755
# 6        0.404071      0.009561         0.008465        0.002952
# 7        3.736255      0.040300         0.027016        0.008357
# 8        0.233853      0.007160         0.006896        0.003564
# 9        2.234593      0.037117         0.027250        0.008148
# 10       0.224447      0.008474         0.013098        0.003487
# 11       2.211694      0.035688         0.024503        0.005986
# 12       0.096300      0.003822         0.009822        0.006277
# 13       0.930129      0.042588         0.027454        0.006554
# 14       0.086443      0.007185         0.009575        0.005971
# 15       0.705144      0.018729         0.027878        0.004059
# 16       0.083928      0.001829         0.008810        0.008268
# 17       0.636108      0.066028         0.023680        0.007607
#
#    param_criterion param_max_features  param_n_estimators  \
# 0    squared_error               None                  10
# 1    squared_error               None                 100
# 2    squared_error               sqrt                  10
# 3    squared_error               sqrt                 100
# 4    squared_error               log2                  10
# 5    squared_error               log2                 100
# 6   absolute_error               None                  10
# 7   absolute_error               None                 100
# 8   absolute_error               sqrt                  10
# 9   absolute_error               sqrt                 100
# 10  absolute_error               log2                  10
# 11  absolute_error               log2                 100
# 12    friedman_mse               None                  10
# 13    friedman_mse               None                 100
# 14    friedman_mse               sqrt                  10
# 15    friedman_mse               sqrt                 100
# 16    friedman_mse               log2                  10
# 17    friedman_mse               log2                 100
#
#                                                params  split0_test_score  \
# 0   {'criterion': 'squared_error', 'max_features':...           0.833806
# 1   {'criterion': 'squared_error', 'max_features':...           0.845606
# 2   {'criterion': 'squared_error', 'max_features':...           0.838592
# 3   {'criterion': 'squared_error', 'max_features':...           0.859029
# 4   {'criterion': 'squared_error', 'max_features':...           0.846699
# 5   {'criterion': 'squared_error', 'max_features':...           0.858359
# 6   {'criterion': 'absolute_error', 'max_features'...           0.823343
# 7   {'criterion': 'absolute_error', 'max_features'...           0.839377
# 8   {'criterion': 'absolute_error', 'max_features'...           0.848135
# 9   {'criterion': 'absolute_error', 'max_features'...           0.860452
# 10  {'criterion': 'absolute_error', 'max_features'...           0.841748
# 11  {'criterion': 'absolute_error', 'max_features'...           0.854661
# 12  {'criterion': 'friedman_mse', 'max_features': ...           0.830833
# 13  {'criterion': 'friedman_mse', 'max_features': ...           0.846439
# 14  {'criterion': 'friedman_mse', 'max_features': ...           0.839131
# 15  {'criterion': 'friedman_mse', 'max_features': ...           0.856371
# 16  {'criterion': 'friedman_mse', 'max_features': ...           0.848153
# 17  {'criterion': 'friedman_mse', 'max_features': ...           0.856975
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.754004           0.830422           0.792743
# 1            0.770901           0.854420           0.818726
# 2            0.780171           0.846145           0.812039
# 3            0.782175           0.861930           0.827042
# 4            0.743221           0.835340           0.815243
# 5            0.782204           0.863875           0.826803
# 6            0.766619           0.836972           0.814052
# 7            0.769688           0.848933           0.825476
# 8            0.774118           0.807521           0.822674
# 9            0.781188           0.852911           0.828636
# 10           0.772229           0.831497           0.808790
# 11           0.779086           0.853691           0.824838
# 12           0.769118           0.836702           0.803554
# 13           0.771454           0.861620           0.818942
# 14           0.760895           0.835960           0.809346
# 15           0.777714           0.861183           0.829460
# 16           0.767446           0.837336           0.816915
# 17           0.780240           0.863156           0.831462
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.812577         0.804711        0.029271               18
# 1            0.837614         0.825453        0.029713                8
# 2            0.826562         0.820702        0.023322               11
# 3            0.843187         0.834672        0.029062                1
# 4            0.804616         0.809024        0.036056               17
# 5            0.840420         0.834332        0.029193                3
# 6            0.823352         0.812868        0.024253               16
# 7            0.834479         0.823591        0.027997                9
# 8            0.819732         0.814436        0.024104               13
# 9            0.841922         0.833022        0.028047                4
# 10           0.828232         0.816499        0.024574               12
# 11           0.844907         0.831437        0.028285                6
# 12           0.827861         0.813614        0.024954               15
# 13           0.833800         0.826451        0.030891                7
# 14           0.824090         0.813885        0.028486               14
# 15           0.839015         0.832749        0.029817                5
# 16           0.841402         0.822250        0.029317               10
# 17           0.840661         0.834499        0.029386                2

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 25
# BMI: 25
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Insurance_charges=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
print("Insurance Charges={}".format(Insurance_charges))
# Out:
# Insurance Charges=[3655.7822943]
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but RandomForestRegressor was fitted with feature names
#   warnings.warn(
