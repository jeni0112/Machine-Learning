# %%
import pandas as pd

# %%
dataset=pd.read_csv("insurance_pre.csv")

# %%
dataset
# Out:
#       age     sex     bmi  children smoker      charges
# 0      19  female  27.900         0    yes  16884.92400
# 1      18    male  33.770         1     no   1725.55230
# 2      28    male  33.000         3     no   4449.46200
# 3      33    male  22.705         0     no  21984.47061
# 4      32    male  28.880         0     no   3866.85520
# ...   ...     ...     ...       ...    ...          ...
# 1333   50    male  30.970         3     no  10600.54830
# 1334   18  female  31.920         0     no   2205.98080
# 1335   18  female  36.850         0     no   1629.83350
# 1336   21  female  25.800         0     no   2007.94500
# 1337   61  female  29.070         0    yes  29141.36030
#
# [1338 rows x 6 columns]

# %%
dataset=pd.get_dummies(dataset,dtype=int,drop_first=True)

# %%
dataset
# Out:
#       age     bmi  children      charges  sex_male  smoker_yes
# 0      19  27.900         0  16884.92400         0           1
# 1      18  33.770         1   1725.55230         1           0
# 2      28  33.000         3   4449.46200         1           0
# 3      33  22.705         0  21984.47061         1           0
# 4      32  28.880         0   3866.85520         1           0
# ...   ...     ...       ...          ...       ...         ...
# 1333   50  30.970         3  10600.54830         1           0
# 1334   18  31.920         0   2205.98080         0           0
# 1335   18  36.850         0   1629.83350         0           0
# 1336   21  25.800         0   2007.94500         0           0
# 1337   61  29.070         0  29141.36030         0           1
#
# [1338 rows x 6 columns]

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
independent=dataset[['age', 'bmi', 'children','sex_male', 'smoker_yes']]

# %%
independent
# Out:
#       age     bmi  children  sex_male  smoker_yes
# 0      19  27.900         0         0           1
# 1      18  33.770         1         1           0
# 2      28  33.000         3         1           0
# 3      33  22.705         0         1           0
# 4      32  28.880         0         1           0
# ...   ...     ...       ...       ...         ...
# 1333   50  30.970         3         1           0
# 1334   18  31.920         0         0           0
# 1335   18  36.850         0         0           0
# 1336   21  25.800         0         0           0
# 1337   61  29.070         0         0           1
#
# [1338 rows x 5 columns]

# %%
dependent=dataset[["charges"]]

# %%
from sklearn.ensemble import AdaBoostRegressor
from sklearn.model_selection import GridSearchCV
param_grid = {
    'n_estimators': [50, 100, 200],
    'learning_rate': [0.01, 0.1, 1],
    'loss': ['linear', 'square', 'exponential']}
grid = GridSearchCV(AdaBoostRegressor(), param_grid, refit = True, verbose= 3,n_jobs=-1)
grid.fit(independent, dependent)
# Out:
# Fitting 5 folds for each of 27 candidates, totalling 135 fits
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\utils\validation.py:1339: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# GridSearchCV(estimator=AdaBoostRegressor(), n_jobs=-1,
#              param_grid={'learning_rate': [0.01, 0.1, 1],
#                          'loss': ['linear', 'square', 'exponential'],
#                          'n_estimators': [50, 100, 200]},
#              verbose=3)

# %%
re=grid.cv_results_
grid_predictions = grid.predict(independent)
from sklearn.metrics import r2_score
r_score=r2_score(dependent,grid_predictions)
print("The R_score value for best parameter {}:".format(grid.best_params_),r_score)
# Out:
# The R_score value for best parameter {'learning_rate': 0.01, 'loss': 'square', 'n_estimators': 50}: 0.8610118771034194

# %%
table=pd.DataFrame.from_dict(re)

# %%
table
# Out:
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.331534      0.010408         0.034590        0.005020
# 1        0.675763      0.058442         0.061276        0.026355
# 2        1.168223      0.029705         0.092750        0.022144
# 3        0.312302      0.005626         0.022550        0.003696
# 4        0.673379      0.049623         0.051813        0.017124
# 5        1.211500      0.030226         0.092195        0.009090
# 6        0.304349      0.006092         0.019136        0.006033
# 7        0.702214      0.051652         0.051644        0.011336
# 8        1.193754      0.030706         0.084449        0.003865
# 9        0.295129      0.012605         0.029162        0.008457
# 10       0.472997      0.032167         0.030210        0.008968
# 11       0.501868      0.085297         0.046887        0.014442
# 12       0.460115      0.051300         0.039292        0.022442
# 13       0.588105      0.011351         0.046633        0.008391
# 14       1.134930      0.066475         0.082948        0.005567
# 15       0.331510      0.013882         0.030493        0.010493
# 16       0.632281      0.029650         0.041773        0.005172
# 17       1.209399      0.059441         0.085720        0.012400
# 18       0.075991      0.010336         0.009055        0.006441
# 19       0.079843      0.015686         0.012576        0.007379
# 20       0.076948      0.022734         0.008495        0.005155
# 21       0.299445      0.009722         0.025965        0.004364
# 22       0.578652      0.015549         0.041385        0.005171
# 23       1.083478      0.026683         0.084981        0.018519
# 24       0.296227      0.012557         0.025310        0.010336
# 25       0.565903      0.009093         0.043060        0.007012
# 26       1.131607      0.031600         0.079409        0.009351
#
#     param_learning_rate   param_loss  param_n_estimators  \
# 0                  0.01       linear                  50
# 1                  0.01       linear                 100
# 2                  0.01       linear                 200
# 3                  0.01       square                  50
# 4                  0.01       square                 100
# 5                  0.01       square                 200
# 6                  0.01  exponential                  50
# 7                  0.01  exponential                 100
# 8                  0.01  exponential                 200
# 9                  0.10       linear                  50
# 10                 0.10       linear                 100
# 11                 0.10       linear                 200
# 12                 0.10       square                  50
# 13                 0.10       square                 100
# 14                 0.10       square                 200
# 15                 0.10  exponential                  50
# 16                 0.10  exponential                 100
# 17                 0.10  exponential                 200
# 18                 1.00       linear                  50
# 19                 1.00       linear                 100
# 20                 1.00       linear                 200
# 21                 1.00       square                  50
# 22                 1.00       square                 100
# 23                 1.00       square                 200
# 24                 1.00  exponential                  50
# 25                 1.00  exponential                 100
# 26                 1.00  exponential                 200
#
#                                                params  split0_test_score  \
# 0   {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.875565
# 1   {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.871820
# 2   {'learning_rate': 0.01, 'loss': 'linear', 'n_e...           0.863511
# 3   {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.872710
# 4   {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.867237
# 5   {'learning_rate': 0.01, 'loss': 'square', 'n_e...           0.854920
# 6   {'learning_rate': 0.01, 'loss': 'exponential',...           0.876070
# 7   {'learning_rate': 0.01, 'loss': 'exponential',...           0.873524
# 8   {'learning_rate': 0.01, 'loss': 'exponential',...           0.869218
# 9   {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.853123
# 10  {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.841520
# 11  {'learning_rate': 0.1, 'loss': 'linear', 'n_es...           0.838812
# 12  {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.813800
# 13  {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.704629
# 14  {'learning_rate': 0.1, 'loss': 'square', 'n_es...           0.628034
# 15  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.848999
# 16  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.817428
# 17  {'learning_rate': 0.1, 'loss': 'exponential', ...           0.743887
# 18  {'learning_rate': 1, 'loss': 'linear', 'n_esti...           0.855609
# 19  {'learning_rate': 1, 'loss': 'linear', 'n_esti...           0.834918
# 20  {'learning_rate': 1, 'loss': 'linear', 'n_esti...           0.852575
# 21  {'learning_rate': 1, 'loss': 'square', 'n_esti...           0.538556
# 22  {'learning_rate': 1, 'loss': 'square', 'n_esti...           0.495141
# 23  {'learning_rate': 1, 'loss': 'square', 'n_esti...           0.503713
# 24  {'learning_rate': 1, 'loss': 'exponential', 'n...           0.615742
# 25  {'learning_rate': 1, 'loss': 'exponential', 'n...           0.544174
# 26  {'learning_rate': 1, 'loss': 'exponential', 'n...           0.525723
#
#     split1_test_score  split2_test_score  split3_test_score  \
# 0            0.790682           0.877437           0.830987
# 1            0.797936           0.875922           0.830137
# 2            0.795340           0.868038           0.828759
# 3            0.800282           0.876036           0.832304
# 4            0.795703           0.872552           0.830032
# 5            0.792455           0.859223           0.824458
# 6            0.791237           0.880861           0.828976
# 7            0.798825           0.878093           0.830653
# 8            0.797293           0.871103           0.829097
# 9            0.787206           0.852058           0.820154
# 10           0.786156           0.834785           0.809894
# 11           0.780747           0.848942           0.810893
# 12           0.761352           0.795016           0.793108
# 13           0.653430           0.720269           0.703650
# 14           0.519711           0.611066           0.593556
# 15           0.795085           0.853555           0.817461
# 16           0.764463           0.808950           0.789407
# 17           0.689141           0.745225           0.730060
# 18           0.769974           0.811251           0.818694
# 19           0.782840           0.833257           0.788388
# 20           0.780551           0.846626           0.821297
# 21           0.427125           0.439551           0.486757
# 22           0.393080           0.412700           0.468067
# 23           0.382054           0.406797           0.439775
# 24           0.509669           0.574822           0.602413
# 25           0.423739           0.491632           0.524210
# 26           0.374393           0.440786           0.469509
#
#     split4_test_score  mean_test_score  std_test_score  rank_test_score
# 0            0.864949         0.847924        0.033131                5
# 1            0.864586         0.848080        0.029825                3
# 2            0.860397         0.843209        0.027656                8
# 3            0.865656         0.849398        0.029058                1
# 4            0.863329         0.845771        0.029123                6
# 5            0.852183         0.836648        0.025245                9
# 6            0.862561         0.847941        0.033656                4
# 7            0.865084         0.849236        0.030201                2
# 8            0.861895         0.845721        0.028564                7
# 9            0.843659         0.831240        0.025013               11
# 10           0.837893         0.822050        0.021111               14
# 11           0.836038         0.823086        0.024596               13
# 12           0.801890         0.793033        0.017420               18
# 13           0.718119         0.700019        0.024259               20
# 14           0.585391         0.587552        0.036972               21
# 15           0.844593         0.831938        0.022299               10
# 16           0.811960         0.798442        0.019441               17
# 17           0.743922         0.730447        0.021387               19
# 18           0.831000         0.817306        0.028048               15
# 19           0.837954         0.815471        0.024488               16
# 20           0.843803         0.828971        0.026428               12
# 21           0.484471         0.475292        0.039536               24
# 22           0.452004         0.444198        0.036962               26
# 23           0.437915         0.434051        0.040858               27
# 24           0.602861         0.581101        0.038130               22
# 25           0.516034         0.499958        0.041666               23
# 26           0.480036         0.458090        0.049982               25

# %%
age_input=float(input("Age:"))
bmi_input=float(input("BMI:"))
children_input=float(input("Children:"))
sex_male_input=int(input("Sex Male 0 or 1:"))
smoker_yes_input=int(input("Smoker Yes 0 or 1:"))
# Out:
# Age: 25
# BMI: 25
# Children: 0
# Sex Male 0 or 1: 0
# Smoker Yes 0 or 1: 0

# %%
Insurance_charges=grid.predict([[age_input,bmi_input,children_input,sex_male_input,smoker_yes_input]])
#change the paramter,play with it.
print("Insurance Charges={}".format(Insurance_charges))
# Out:
# Insurance Charges=[4784.68062377]
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but AdaBoostRegressor was fitted with feature names
#   warnings.warn(
